# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = sns.load_dataset("titanic")

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# EDA

# %%
sns.barplot(data=df, x="sex", y="survived")
plt.show()

# %%
df["sex"].value_counts()
# Out:
# sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
sns.catplot(data=df, x="pclass", hue="survived", kind="count")
plt.show()

# %%
sns.histplot(data=df, x="age", hue="survived")
plt.show()

# %%
sns.countplot(data=df, x="who", hue="survived")
plt.show()

# %%
# feature engineering

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df = df.drop(["deck", "embark_town"], axis=1)

# %%
df.isnull().sum()
# Out:
# survived        0
# pclass          0
# sex             0
# age           177
# sibsp           0
# parch           0
# fare            0
# embarked        2
# class           0
# who             0
# adult_male      0
# alive           0
# alone           0
# dtype: int64

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df["age"] = df["age"].fillna(df["age"].median())
df["embarked"] = df["embarked"].fillna(df["embarked"].mode()[0])

# %%
df.isnull().sum()
# Out:
# survived      0
# pclass        0
# sex           0
# age           0
# sibsp         0
# parch         0
# fare          0
# embarked      0
# class         0
# who           0
# adult_male    0
# alive         0
# alone         0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   survived    891 non-null    int64
#  1   pclass      891 non-null    int64
#  2   sex         891 non-null    object
#  3   age         891 non-null    float64
#  4   sibsp       891 non-null    int64
#  5   parch       891 non-null    int64
#  6   fare        891 non-null    float64
#  7   embarked    891 non-null    object
#  8   class       891 non-null    category
#  9   who         891 non-null    object
#  10  adult_male  891 non-null    bool
#  11  alive       891 non-null    object
#  12  alone       891 non-null    bool
# dtypes: bool(2), category(1), float64(2), int64(4), object(4)
# memory usage: 72.5+ KB

# %%
df["sex"].value_counts()
# Out:
# sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
df["class"].value_counts()
# Out:
# class
# Third     491
# First     216
# Second    184
# Name: count, dtype: int64

# %%
df["embarked"].value_counts()
# Out:
# embarked
# S    646
# C    168
# Q     77
# Name: count, dtype: int64

# %%
df["who"].value_counts()
# Out:
# who
# man      537
# woman    271
# child     83
# Name: count, dtype: int64

# %%
df["adult_male"] = df["adult_male"].astype(int)
df["alone"] = df["alone"].astype(int)

# %%
X = df.drop("survived", axis=1)
y = df["survived"]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 15)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

# %%
categorical_cols = ["sex", "class", "embarked", "who"]

preprocessor = ColumnTransformer(transformers= [
    ("cat", OneHotEncoder(drop="first", handle_unknown= "ignore"), categorical_cols)
], remainder= "passthrough"
                                )

X_train = preprocessor.fit_transform(X_train)
X_test = preprocessor.transform(X_test)

# %%
encoded_cols = preprocessor.get_feature_names_out()

# %%
X_train = pd.DataFrame(X_train, columns = encoded_cols)
X_test = pd.DataFrame(X_test, columns = encoded_cols)

# %%
# !pip install lightgbm
# Out:
# Requirement already satisfied: lightgbm in c:\users\irm\miniconda3\lib\site-packages (4.6.0)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\irm\miniconda3\lib\site-packages (from lightgbm) (2.3.3)
# Requirement already satisfied: scipy in c:\users\irm\miniconda3\lib\site-packages (from lightgbm) (1.16.2)

# %%
import lightgbm as lgb

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
clf = lgb.LGBMClassifier(verbosity=-1)
clf.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 2
#       1 clf = lgb.LGBMClassifier(verbosity=-1)
# ----> 2 clf.fit(X_train, y_train)
#
# File ~\miniconda3\Lib\site-packages\lightgbm\sklearn.py:1560, in LGBMClassifier.fit(self, X, y, sample_weight, init_score, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_metric, feature_name, categorical_feature, callbacks, init_model)
#    1557         else:
#    1558             valid_sets.append((valid_x, self._le.transform(valid_y)))
# -> 1560 super().fit(
#    1561     X,
#    1562     _y,
#    1563     sample_weight=sample_weight,
#    1564     init_score=init_score,
#    1565     eval_set=valid_sets,
#    1566     eval_names=eval_names,
#    1567     eval_sample_weight=eval_sample_weight,
#    1568     eval_class_weight=eval_class_weight,
#    1569     eval_init_score=eval_init_score,
#    1570     eval_metric=eval_metric,
#    1571     feature_name=feature_name,
#    1572     categorical_feature=categorical_feature,
#    1573     callbacks=callbacks,
#    1574     init_model=init_model,
#    1575 )
#    1576 return self
#
# File ~\miniconda3\Lib\site-packages\lightgbm\sklearn.py:1049, in LGBMModel.fit(self, X, y, sample_weight, init_score, group, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_group, eval_metric, feature_name, categorical_feature, callbacks, init_model)
#    1046 evals_result: _EvalResultDict = {}
#    1047 callbacks.append(record_evaluation(evals_result))
# -> 1049 self._Booster = train(
#    1050     params=params,
#    1051     train_set=train_set,
#    1052     num_boost_round=self.n_estimators,
#    1053     valid_sets=valid_sets,
#    1054     valid_names=eval_names,
#    1055     feval=eval_metrics_callable,  # type: ignore[arg-type]
#    1056     init_model=init_model,
#    1057     callbacks=callbacks,
#    1058 )
#    1060 # This populates the property self.n_features_, the number of features in the fitted model,
#    1061 # and so should only be set after fitting.
#    1062 #
#    1063 # The related property self._n_features_in, which populates self.n_features_in_,
#    1064 # is set BEFORE fitting.
#    1065 self._n_features = self._Booster.num_feature()
#
# File ~\miniconda3\Lib\site-packages\lightgbm\engine.py:297, in train(params, train_set, num_boost_round, valid_sets, valid_names, feval, init_model, keep_training_booster, callbacks)
#     295 # construct booster
#     296 try:
# --> 297     booster = Booster(params=params, train_set=train_set)
#     298     if is_valid_contain_train:
#     299         booster.set_train_data_name(train_data_name)
#
# File ~\miniconda3\Lib\site-packages\lightgbm\basic.py:3656, in Booster.__init__(self, params, train_set, model_file, model_str)
#    3649     self.set_network(
#    3650         machines=machines,
#    3651         local_listen_port=params["local_listen_port"],
#    3652         listen_time_out=params.get("time_out", 120),
#    3653         num_machines=params["num_machines"],
#    3654     )
#    3655 # construct booster object
# -> 3656 train_set.construct()
#    3657 # copy the parameters from train_set
#    3658 params.update(train_set.get_params())
#
# File ~\miniconda3\Lib\site-packages\lightgbm\basic.py:2590, in Dataset.construct(self)
#    2585             self._set_init_score_by_predictor(
#    2586                 predictor=self._predictor, data=self.data, used_indices=used_indices
#    2587             )
#    2588 else:
#    2589     # create train
# -> 2590     self._lazy_init(
#    2591         data=self.data,
#    2592         label=self.label,
#    2593         reference=None,
#    2594         weight=self.weight,
#    2595         group=self.group,
#    2596         init_score=self.init_score,
#    2597         predictor=self._predictor,
#    2598         feature_name=self.feature_name,
#    2599         categorical_feature=self.categorical_feature,
#    2600         params=self.params,
#    2601         position=self.position,
#    2602     )
#    2603 if self.free_raw_data:
#    2604     self.data = None
#
# File ~\miniconda3\Lib\site-packages\lightgbm\basic.py:2123, in Dataset._lazy_init(self, data, label, reference, weight, group, init_score, predictor, feature_name, categorical_feature, params, position)
#    2121     categorical_feature = reference.categorical_feature
#    2122 if isinstance(data, pd_DataFrame):
# -> 2123     data, feature_name, categorical_feature, self.pandas_categorical = _data_from_pandas(
#    2124         data=data,
#    2125         feature_name=feature_name,
#    2126         categorical_feature=categorical_feature,
#    2127         pandas_categorical=self.pandas_categorical,
#    2128     )
#    2129 elif _is_pyarrow_table(data) and feature_name == "auto":
#    2130     feature_name = data.column_names
#
# File ~\miniconda3\Lib\site-packages\lightgbm\basic.py:868, in _data_from_pandas(data, feature_name, categorical_feature, pandas_categorical)
#     864 df_dtypes.append(np.float32)
#     865 target_dtype = np.result_type(*df_dtypes)
#     867 return (
# --> 868     _pandas_to_numpy(data, target_dtype=target_dtype),
#     869     feature_name,
#     870     categorical_feature,
#     871     pandas_categorical,
#     872 )
#
# File ~\miniconda3\Lib\site-packages\lightgbm\basic.py:814, in _pandas_to_numpy(data, target_dtype)
#     810 def _pandas_to_numpy(
#     811     data: pd_DataFrame,
#     812     target_dtype: "np.typing.DTypeLike",
#     813 ) -> np.ndarray:
# --> 814     _check_for_bad_pandas_dtypes(data.dtypes)
#     815     try:
#     816         # most common case (no nullable dtypes)
#     817         return data.to_numpy(dtype=target_dtype, copy=False)
#
# File ~\miniconda3\Lib\site-packages\lightgbm\basic.py:805, in _check_for_bad_pandas_dtypes(pandas_dtypes_series)
#     799 bad_pandas_dtypes = [
#     800     f"{column_name}: {pandas_dtype}"
#     801     for column_name, pandas_dtype in pandas_dtypes_series.items()
#     802     if not _is_allowed_numpy_dtype(pandas_dtype.type)
#     803 ]
#     804 if bad_pandas_dtypes:
# --> 805     raise ValueError(
#     806         f"pandas dtypes must be int, float or bool.\nFields with bad pandas dtypes: {', '.join(bad_pandas_dtypes)}"
#     807     )
#
# ValueError: pandas dtypes must be int, float or bool.
# Fields with bad pandas dtypes: cat__sex_male: object, cat__class_Second: object, cat__class_Third: object, cat__embarked_Q: object, cat__embarked_S: object, cat__who_man: object, cat__who_woman: object, remainder__pclass: object, remainder__age: object, remainder__sibsp: object, remainder__parch: object, remainder__fare: object, remainder__adult_male: object, remainder__alive: object, remainder__alone: object
